# %%
import matplotlib.pyplot as plt
import csv
import math
import numpy as np 
plt.rcParams['figure.figsize'] = [10, 10]

# %%
# 100nm, alpha as parameter
T_c = 1.183
k = 8.617333262145e-5
bgap = T_c*1.764*k
T = np.arange(0.0001, 0.7,0.01) 
a = 0.1 # alpha

def temp(T): # put temp in terms of K instead of mK
    return T/1000

def dff(f,a): # 100*df/f
    return 100*(f-a)/a

def df(T):
    return -.5*100*a*np.sqrt((bgap*np.pi)/(2*k*T))*np.exp(-bgap/(k*T)) # alpha = 0.1

t = np.array([19,150,216,247,350,420,506])

res_1 = np.array([7.005627280061895370,
7.005607951177417755,
7.005607602423564911,
7.005485310682896614,
7.003825954888551712,
6.999578449061882019,
6.984361085931580544])
res_2 = np.array([7.031065655005873680,
7.031060902916087151, 
7.030996826366641045,
7.030775440567755699,
7.029152469142274857,
7.025802838954657555,
7.013474899483192444])
res_3 = np.array([7.109005757172023773, # 506: 7.125083951748528481 removed
7.109008910294591904,
7.108886612279829979,
7.108689209254198074,
7.106997952166652679,
7.104043913815608978])
res_4 = np.array([7.125958470425599098,
7.125943049211584091,
7.125922380178226471,
7.125702344930241585,
7.124093458074416161,
7.119860285850705147,
7.089164999630832672])
res_5 = np.array([7.197916705359072685,
7.197841316434438705,
7.197823262177887917,
7.197635779400767326,
7.196087699975780487,
7.204174270094560623,
7.176618370124832153])
res_6 = np.array([7.210495164806170464, # 420: -3.193546155634500504 removed
7.210572309668688774,
7.210499268586855888,
7.210277709440767288,
7.208886004027139664,
7.175849999951073647])
res_7 = np.array([7.296016128159790039,
7.296115854465219498,
7.296062571684633255,
7.295913730716929436,
7.294382298793370247,
7.289905007580610275,
7.279934632413441658])
res_8 = np.array([7.407615508085698128, # 506: 1.770985773493574080 removed
7.407613340941244125,
7.407545144166743279,
7.407354123895180702,
7.414241484604441643,
7.395465713090818405])
res_9 = np.array([7.434776310528495789, # 506: 8.806900578864421844 removed
7.434669359526778221,
7.434639663063154221,
7.434409764207485199,
7.432608419344367027,
7.428810618449575424])



plt.plot(temp(t), dff(res_1,7.005627280061895370), linestyle='None', marker="$1$")
plt.plot(temp(t), dff(res_2,7.031065655005873680), linestyle='None', marker="$2$")
plt.plot(np.array([19,150,216,247,350,420])/1000, dff(res_3,7.109005757172023773), linestyle='None', marker="$3$")
plt.plot(temp(t), dff(res_4,7.125958470425599098), linestyle='None', marker="$4$")
plt.plot(temp(t), dff(res_5,7.197916705359072685), linestyle='None', marker="$5$")
plt.plot(np.array([19,150,216,247,350,506])/1000, dff(res_6,7.210495164806170464), linestyle='None', marker="$6$")
plt.plot(temp(t), dff(res_7,7.296016128159790039), linestyle='None', marker="$7$")
plt.plot(np.array([19,150,216,247,350,420])/1000, dff(res_8,7.407615508085698128), linestyle='None', marker="$8$")
plt.plot(np.array([19,150,216,247,350,420])/1000, dff(res_9,7.434776310528495789), linestyle='None', marker="$9$")

plt.plot(T, df(T))
plt.title('Relative Frequency Shift')
plt.xlabel('Temperature (K)')
plt.ylabel('df/f')
plt.show()

# %%
# third resonator 100nm with bandgap as parameter, alpha = 1 (test comparing results to 
# fig2a: https://arxiv.org/pdf/1802.01858.pdf)

bgap = 288e-6
k = 8.617333262145e-5
T = np.arange(0.0001, 0.8,0.01) 
a = 1 # alpha


def temp(T):
    return T/1000
def dff(f,a):
    return 100*(f-a)/a
def df(T):
    return -.5*100*a*np.sqrt((bgap*np.pi)/(2*k*T))*np.exp(-bgap/(k*T))


y = np.array([7.031065655005873680,
7.031060902916087151, 
7.030996826366641045,
7.030775440567755699,
7.029152469142274857,
7.025802838954657555,
7.013474899483192444])

t = np.array([19,150,216,247,350,420,506])

plt.plot(temp(t), dff(y, 7.031065655005873680), 'ro')

plt.plot(T, df(T))
plt.title('Relative Frequency Shift')
plt.xlabel('Temperature (K)')
plt.ylabel('df/f')
plt.show()

# %%
# 200nm, alpha as parameter
T_c = 1.183
k = 8.617333262145e-5
bgap = T_c*1.764*k
T = np.arange(0.0001, 0.7,0.01) 
a= 0.05 # alpha


def temp(T):
    return T/1000

def dff(f,a):
    return 100*(f-a)/a

def df(T):
    return -.5*100*a*np.sqrt((bgap*np.pi)/(2*k*T))*np.exp(-bgap/(k*T)) # alpha = 0.05

t = np.array([22,152,219,350,410,473,696])

res_1 = np.array([7.011544483475106239,
7.011537697794591904,
7.011530071857769012,
7.010851937500276566,
7.009932335530532837,
7.008084006688772202,
6.990470836527594566])

res_2 = np.array([7.118832126205295563, # 696: -4.575951228876198769 removed
7.118836147934134483,
7.118818216058661461,
7.117488225743219376,
7.115556857542923927,
7.116700743714865685
])

res_3 = np.array([7.229904315277852058,
7.229908458836348534,
7.229894819911463737,
7.228624518628759384,
7.226735682975978851,
7.227899836091938019,
7.219449902936135292])
res_4 = np.array([7.332444778773498535,
7.332435403874668121,
7.332434389333161354,
7.331075581167672157,
7.328845477471757889,
7.330495825693182945,
7.316196058952113152])
res_5 = np.array([7.431791537718349457,
7.431784059949509621,
7.431800280793894768,
7.430502534031608582,
7.428505612597316742,
7.429900981638590813,
7.414265526146053314])
res_6 = np.array([7.536706392728127480, # 696: 7.138911962530783653 removed
7.536711757152538300,
7.536715127775473595,
7.535434114280804634,
7.533243512213478088,
7.534094054526905060])



plt.plot(temp(t), dff(res_1,7.011544483475106239), linestyle='None', marker="$1$")
plt.plot(np.array([22,152,219,350,410,473])/1000, dff(res_2,7.118832126205295563), linestyle='None', marker="$2$")
plt.plot(temp(t), dff(res_3,7.229904315277852058), linestyle='None', marker="$3$")
plt.plot(temp(t), dff(res_4,7.332444778773498535), linestyle='None', marker="$4$")
plt.plot(temp(t), dff(res_5,7.431791537718349457), linestyle='None', marker="$5$")
plt.plot(np.array([22,152,219,350,410,473])/1000, dff(res_6,7.536706392728127480), linestyle='None', marker="$6$")


plt.plot(T, df(T))
plt.title('Relative Frequency Shift')
plt.xlabel('Temperature (K)')
plt.ylabel('df/f')
plt.show()

# %%
# 25nmW, alpha as parameter

T_c = 1.32
k = 8.617333262145e-5
bgap = T_c*1.764*k
T = np.arange(0.0001, 0.7,0.01) 
a = 0.5 # alpha

def temp(T):
    return T/1000

def dff(f,a):
    return 100*(f-a)/a

def df(T):
    return -.5*100*a*np.sqrt((bgap*np.pi)/(2*k*T))*np.exp(-bgap/(k*T))

t = np.array([33,152,248,332,410])

res_1 = np.array([5.094227917010381699,
5.094443967779386520,
5.093421018033938408,
5.090183218012177467,
5.082189703518279076])
res_2 = np.array([5.117958779295836449,
5.117334950858039856,
5.116051935539927483,
5.112179691175637245,
5.100688013778455734])
res_3 = np.array([5.156851878426650047, #410:-1.11600199276460434 removed
5.156767836259572029,
5.157152604824909210,
5.140551032886578560])
res_4 = np.array([5.192599364561628342,
5.192542537751080513,
5.192795125057066917,
5.188164263218951225,
5.180377894448453903])
res_5 = np.array([5.271569183567074776,
5.271506485544350624,
5.271887684146965027,
5.266929374154053688,
5.271513938212632179])
res_6 = np.array([5.266583934395393372,
5.266512307532757759,
5.266825001144546509,
5.263116410627233505,
5.264259491725402832])
res_7 = np.array([5.336134252338922501,
5.336024821452198982,
5.336308120227090836,
5.323550145338426590,
5.334074057329415321])
res_8 = np.array([5.372299857120543480, #410: 2.386318785811564026 removed
5.372205723661316872,
5.372484815922369003,
5.367664268004384041])
res_9 = np.array([5.437304303784043312,
5.437187984635293961,
5.437471946459121704,
5.432265879132812500,
5.420251168465004921])




plt.plot(temp(t), dff(res_1,5.094227917010381699),  linestyle='None', marker="$1$")
plt.plot(temp(t), dff(res_2,5.117958779295836449),  linestyle='None', marker=r"$2$")
plt.plot(np.array([33,152,248,332])/1000, dff(res_3,5.156851878426650047),  linestyle='None', marker=r"$3$")
plt.plot(temp(t), dff(res_4,5.192599364561628342), linestyle='None', marker=r"$4$")
plt.plot(temp(t), dff(res_5,5.271569183567074776),  linestyle='None', marker="$5$")
plt.plot(temp(t), dff(res_6,5.266583934395393372),  linestyle='None', marker=r"$6$")
plt.plot(temp(t), dff(res_7,5.336134252338922501),  linestyle='None', marker=r"$7$")
plt.plot(np.array([33,152,248,332])/1000, dff(res_8,5.372299857120543480), linestyle='None', marker=r"$8$")
plt.plot(temp(t), dff(res_9,5.437304303784043312),  linestyle='None', marker=r"$9$")


plt.plot(T, df(T))
plt.title('Relative Frequency Shift')
plt.xlabel('Temperature (K)')
plt.ylabel('df/f')
plt.show()

# %%
# 25nmN, alpha as parameter

T_c = 1.32
k = 8.617333262145e-5
bgap = T_c*1.764*k
T = np.arange(0.0001, 0.7,0.01) 
a = 0.5

def temp(T):
    return T/1000

def dff(f,a):
    return 100*(f-a)/a

def df(T):
    return -.5*100*a*np.sqrt((bgap*np.pi)/(2*k*T))*np.exp(-bgap/(k*T))
 
t = np.array([33,152,248,332])

res_1 = np.array([7.339101112437623978,
5.092424816626448631,
5.091389031784671783,
-2.815918700102680500])
res_2 = np.array([5.123415183783755302,
5.123473536158632278,
5.122546399072138786,
5.121375288470394135])
res_3 = np.array([5.156844195105790138, # 332:-2.098823746829670938 removed
5.156757725828300476,
5.156842016959704399])
res_4 = np.array([5.192622991422195435,
5.192542496800818443,
5.192789059792994499,
5.187746810914811134])
res_5 = np.array([5.261758740734666824,
5.261666177743316650,
5.261926482038288116,
5.257380794057344437])
res_6 = np.array([5.266614261249268532, # 332: 0.000000000000000000 removed
5.266525548706731796,
5.266807710491349220])
res_7 = np.array([5.336254530261662483,
5.336168314042711258,
5.336405128688735962,
5.332409947417476654])
res_8 = np.array([5.372311643400382996,
5.372206414322560310,
5.372466166215329170,
5.367575075633089066])
res_9 = np.array([5.437338862070693016,
5.437205178727913857,
5.437488893388181686,
5.433543746396035194])




#plt.plot(temp(t), dff(res_1,7.339101112437623978),  linestyle='None', marker="$1$") -- f(0) is not correct
plt.plot(temp(t), dff(res_2,5.123415183783755302),  linestyle='None', marker=r"$2$")
plt.plot(np.array([33,152,248])/1000, dff(res_3,5.156844195105790138),  linestyle='None', marker=r"$3$")
plt.plot(temp(t), dff(res_4,5.192622991422195435), linestyle='None', marker=r"$4$")
plt.plot(temp(t), dff(res_5,5.261758740734666824),  linestyle='None', marker="$5$")
plt.plot(np.array([33,152,248])/1000, dff(res_6,5.266614261249268532),  linestyle='None', marker=r"$6$")
plt.plot(temp(t), dff(res_7,5.336254530261662483),  linestyle='None', marker=r"$7$")
plt.plot(temp(t), dff(res_8,5.372311643400382996), linestyle='None', marker=r"$8$")
plt.plot(temp(t), dff(res_9,5.437338862070693016),  linestyle='None', marker=r"$9$")


plt.plot(T, df(T))
plt.title('Relative Frequency Shift')
plt.xlabel('Temperature (K)')
plt.ylabel('df/f')
plt.show()
