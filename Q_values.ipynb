# %%
import matplotlib.pyplot as plt
import csv
import math
import numpy as np 
plt.rcParams['figure.figsize'] = [10, 10]

# %%
# 100nm,

def temp(T): # put temp in terms of K instead of mK
    return T/1000

t = np.array([19,150,216,247,350,420,506])

res_1 = np.array([9.121762341326060778,
                 9.299826519597472725,
                  8.375446764879025068,
                  7.994390696324338933,
                  4.072136405341697355,
                  2.126472371301539624,
                  1.216901851894981377
                 ])
res_2 = np.array([1.639491555379493093,
                 1.727202748021081788,
                 1.751820580827838512,
                 1.374089857622645241,
                 1.317728825307464604,
                 5.629785579992363864,
                  4.293707470393345034
                 ])
res_3 = np.array([5.004259195089425702,
                 1.040282466586344344,
                 5.608755245305897915,
                 5.457195842002141035,
                 2.450547507176871022,
                 1.233604099249287401,
                  1.602641305322349012
                 ])
res_4 = np.array([2.540692686622962810,
                 2.593092092690623303,
                 2.616361828338462146,
                 2.596955573876699418,
                 1.511064253186110591,
                 4.819899771830844770,
                  1.690473201358909989
                 ])
res_5 = np.array([5.330448320726393831,
                  5.051155718919875653,
                 5.023397109303823527,
                 4.528998008793851113,
                 1.697564151209676766,
                  7.805401717879939270,
                  2.814961333419946072
                 ])
res_6 = np.array([4.243704223233887205,
                 3.395496923954698559,
                 3.753765914486506063,
                 3.181040887850012950,
                 1.478791443984415992,
                  3.328083697204241957,
                  1.998342578460559480
                 ])
res_7 = np.array([1.839482339364194104,
                 2.233691418778104435,
                 2.145410233296593560,
                 2.208553608934667864,
                 1.548641362614886475,
                  3.985197200537892854,
                  4.904195673734035950
                 ])
res_8 = np.array([5.958872444357528366, # 506 missing data
                 6.891205075494200173,
                 7.021019706656307790,
                 5.651619462931786984,
                 2.761997327555835363,
                  5.058646461543589226
                 ])
res_9 = np.array([3.085006188239841322,
                 3.026861508611056706,
                 3.187860587578933973,
                 3.028004070296978171,
                 1.820268383601447795,
                  1.117433290781245432,
                  2.486096849082829590
                 ])



plt.plot(temp(t), res_1, linestyle='None', marker="$1$")
plt.plot(temp(t), res_2, linestyle='None', marker="$2$")
plt.plot(temp(t), res_3, linestyle='None', marker="$3$")
plt.plot(temp(t), res_4, linestyle='None', marker="$4$")
plt.plot(temp(t), res_5, linestyle='None', marker="$5$")
plt.plot(temp(t), res_6, linestyle='None', marker="$6$")
plt.plot(temp(t), res_7, linestyle='None', marker="$7$")
plt.plot(np.array([19,150,216,247,350,420])/1000, res_8, linestyle='None', marker="$8$")
plt.plot(temp(t), res_9, linestyle='None', marker="$9$")

#plt.title('Q(T)')
plt.xlabel('Temperature (K)')
plt.ylabel('Q')
plt.show()

# %%
# 200nm,

def temp(T): # put temp in terms of K instead of mK
    return T/1000

t = np.array([22,152,219,350,410,473,696])

res_1 = np.array([4167.135365842868,
 4140.568435281799,
 4100.643428224058,
 3172.700648465393,
 2580.7859397888856,
 1860.550863878133,
 680.3564949277476])
res_2 = np.array([6068.712845263021, # 696 removed
 6049.158259665959,
 5935.800429192451,
 3450.2111577016362,
 2308.5603788989088,
 1602.3376952778947])
res_3 = np.array([3221.113323183686, # 696 removed
 3178.502703842293,
 3145.4325547659337,
 2391.2230926075426,
 1841.5700646156522,
 1310.8212347462186])
res_4 = np.array([903.1331636171158,
 900.1637159432352,
 896.3993058337294,
 787.2530766182582,
 684.4956094619886,
 543.6204138095769,
 164.84868379544633])
res_5 = np.array([697.9354825042221,
 699.3709350969267,
 700.2672248529321,
 659.2531895581227,
 599.8227309012311,
 472.8266281546295,
 158.7977683732925])
res_6 = np.array([2124.07674732235, # 696 removed
 2143.3936538410717,
 2131.631075862472,
 1739.2270297417444,
 1380.4419888881841,
 1107.9937697624869])



plt.plot(temp(t), res_1, linestyle='None', marker="$1$")
plt.plot(np.array([22,152,219,350,410,473])/1000, res_2, linestyle='None', marker="$2$")
plt.plot(np.array([22,152,219,350,410,473])/1000, res_3, linestyle='None', marker="$3$")
plt.plot(temp(t), res_4, linestyle='None', marker="$4$")
plt.plot(temp(t), res_5, linestyle='None', marker="$5$")
plt.plot(np.array([22,152,219,350,410,473])/1000, res_6, linestyle='None', marker="$6$")


#plt.title('Q(T)')
plt.xlabel('Temperature (K)')
plt.ylabel('Q')
plt.show()

# %%
# 25nmW

def temp(T): # put temp in terms of K instead of mK
    return T/1000

t = np.array([33,152,248,332])

res_1 = np.array([7571.933700385673,
 7111.692629835265,
 0.003402781735678793])
res_2 = np.array([6326.099477696122, 4631.806290423128, 4951.705742803409, 2229.966957645516])
res_3 = np.array([7809.73039419032, 7051.77753715077, 4911.187500210891])
res_4 = np.array([5156.815675038549, 4802.7678386431135, 3351.1789622014285, 938.6224386718912])
res_5 = np.array([7738.139117129203, 7165.941097345099, 4319.667338685582, 1922.518359061447])
res_6 = np.array([6382.39710129424, 6181.763147736996, 3844.650229422017]) # 332 removed
res_7 = np.array([7061.748517856107, 7238.864642475279, 3652.375573984467, 1451.324962474357])
res_8 = np.array([3851.914276091301, 4083.5310091301158, 3079.1943391229483, 1046.9646340037464])
res_9 = np.array([3027.781014981294, 3093.407402038833, 2220.0979077706443, 1728.3572572039488])




plt.plot(np.array([33,248,332])/1000, res_1, linestyle='None', marker="$1$")
plt.plot(temp(t), res_2, linestyle='None', marker="$2$")
plt.plot(np.array([33,152,248])/1000, res_3, linestyle='None', marker="$3$")
plt.plot(temp(t), res_4, linestyle='None', marker="$4$")
plt.plot(temp(t), res_5, linestyle='None', marker="$5$")
plt.plot(np.array([33,152,248])/1000, res_6, linestyle='None', marker="$6$")
plt.plot(temp(t), res_7, linestyle='None', marker="$7$")
plt.plot(temp(t), res_8, linestyle='None', marker="$8$")
plt.plot(temp(t), res_9, linestyle='None', marker="$9$")


#plt.title('Q(T)')
plt.xlabel('Temperature (K)')
plt.ylabel('Q')
plt.show()

# %%
# 25nmW

def temp(T): # put temp in terms of K instead of mK
    return T/1000

t = np.array([33,152,248,332, 410])

res_1 = np.array([857.5564640087315,
 382.4786168418859,
 1080.8901558778953,
 418.70884684025685,
 727.3452086491392])
res_2 = np.array([426.1152088295011,
 421.7402676298424,
 474.0767666567649,
 315.2713381879716,
 314.57998198363265])
res_3 = np.array([7476.469362617156,
 6656.676350051159,
 5190.841185691035,
 240.28026294501143])
res_4 = np.array([5004.339730177318,
 4362.825183449167,
 3713.3223913425736,
 683.4243348730265,
 694.6811444792196])
res_5 = np.array([6509.035785353948,
 6376.18991157255,
 3819.6964736042796,
 1319.6764538178375,
 508.93509913409275])
res_6 = np.array([6458.74767031846,
 6572.015486478886,
 3720.9276669708556,
 801.2867892833106,
 217.88866749652655])
res_7 = np.array([4461.902757613689,
 4179.416611930886,
 2980.7462153024526,
 317.84775289060786,
 2586.6953996337143])
res_8 = np.array([3891.5187735666423,
 4198.403692420347,
 3290.4010211068626,
 1198.9104390286027])
res_9 = np.array([2887.3080942287474,
 3199.0154165083463,
 1968.260304548082,
 1112.1204272136522,
 345.8369406238169])




plt.plot(temp(t), res_1, linestyle='None', marker="$1$")
plt.plot(temp(t), res_2, linestyle='None', marker="$2$")
plt.plot(np.array([33,152,248,332])/1000, res_3, linestyle='None', marker="$3$")
plt.plot(temp(t), res_4, linestyle='None', marker="$4$")
plt.plot(temp(t), res_5, linestyle='None', marker="$5$")
plt.plot(temp(t), res_6, linestyle='None', marker="$6$")
plt.plot(temp(t), res_7, linestyle='None', marker="$7$")
plt.plot(np.array([33,152,248,332])/1000,  res_8, linestyle='None', marker="$8$")
plt.plot(temp(t), res_9, linestyle='None', marker="$9$")



#plt.title('Q(T)')
plt.xlabel('Temperature (K)')
plt.ylabel('Q')
plt.show()
